# %% [markdown]
# # Convolutional Neural Network (CNN) from scratch
# <em>adapted from Keras_CNN  and Keras_CNN_Tensorboard code</em>

# %% [markdown]
# ### Import libraries - make sure kernel is Python 3

# %%
# IF RUNNING FOR THE FIRST TIME ON AWS
#!pip3 install pillow

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten
from keras.optimizers import SGD, Adam
from keras import backend as K
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
#import PIL
from PIL import Image
import pandas as pd
import random
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Set seed

# %%
np.random.seed()

# %% [markdown]
# ### Import data

# %%
data = pd.read_csv('id_genre_pairs.csv')
genre_names = data.columns[1:]
print(genre_names)
movie_ids = list(data['movie_id'])
data = np.array(data)
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Mystery', 'Romance',
#        'Science Fiction', 'Thriller', 'War', 'Western'],
#       dtype='object')

# %%
def convert_data_to_size(width,height):
    ####Convert Data to same size 
    for row in data:
        try:
            img = Image.open('Movie Posters/'+str(row[0])+'.jpg')
            img = img.resize((width,height), PIL.Image.ANTIALIAS)
            img.save('Movie Posters Resized '+str(width)+"x"+str(height)+'/'+str(row[0]) + ".jpg", "JPEG")
        except:
            pass

# %%
import os
files = [i for i in os.listdir('Movie Posters Resized 32x32') if i[-3:] == 'jpg']
random.shuffle(files)

training_indices = files[:int(len(files)*0.8)]
test_indices = files[int(len(files)*0.8):]

test = []
test_labels = []
for i in test_indices:
    try:
        img = load_img('Movie Posters Resized 32x32/'+i)
        test.append(img_to_array(img))
        idx = int(i[:i.index(".")])
        for row in data:
            if row[0] == idx:
                test_labels.append(row[1:])
                break
    except:
        pass

# %%
train = []
train_labels = []
for i in training_indices:
    #try:
    img = load_img('Movie Posters Resized 32x32/'+i)
    train.append(img_to_array(img))
    idx = int(i[:i.index(".")])
    for row in data:
        if row[0] == idx:
            train_labels.append(row[1:])
            break
    #except:
        #pass

# %% [markdown]
# ### Reshape data to tell Keras there is only one channel

# %%
img_rows, img_cols = 32, 32
num_classes = 17

x_train = np.array(train) 
x_test = np.array(test)

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

# %% [markdown]
# ### Normalize images to [0,1]

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# interestingly the keras example code does not center the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (11757, 32, 32, 3)
# x_test shape: (2940, 32, 32, 3)
# 11757 train samples
# 2940 test samples

# %% [markdown]
# ### Create the network structure

# %%
import keras.backend as K

# Custom metrics : code adapted from https://github.com/fchollet/keras/issues/5705

def recall_s(y_true, y_pred):
    """Recall metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    threshold = 0.1
    y_pred = K.cast(K.greater(y_pred, threshold), K.floatx())
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    actual_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (actual_positives + K.epsilon())
    return recall

def precision_s(y_true, y_pred):
    """Precision metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    threshold = 0.1
    y_pred = K.cast(K.greater(y_pred, threshold), K.floatx())
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
from sklearn.metrics import hamming_loss, precision_score, recall_score, f1_score
import keras.backend as K
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Dropout
from keras import regularizers

def accuracy_with_threshold(y_true, y_pred):
    threshold = 0.1
    y_pred = K.cast(K.greater(y_pred, threshold), K.floatx())
    return K.mean(K.equal(y_true, y_pred))

# %%
# smaller batch size means noisier gradient, but more updates per epoch
#batch_size = 256
batch_size=512 # Just for running locally - change this!
# number of iterations over the complete training data
#epochs = 50
epochs=1 # Just for testing - change this!

# %%
precisions = []
recalls = []
f1s = []
parameters = []
model_histories = []
# CV for number of layers, number of dense layers, sgd vs. adam, regularization constant, and learning rate 
for n_conv_layers in [1,2,3]:
    for n_dense_layers in [1,2]:
        for lrate in [0.0005,0.001,0.005,0.01,0.1]:
            for adaptive_change in [0.01,0.05]:
                log_dir_string = "cv"
                log_dir_string += str(lrate)
                log_dir_string += str(adaptive_change)
                K.clear_session()
                model = Sequential()
                model.add(Conv2D(16, kernel_size=(5, 5), 
                                 activation='relu', 
                                 kernel_regularizer=regularizers.l2(0.01),
                                 input_shape=input_shape))
                model.add(Dropout(0.2))
                model.add(MaxPooling2D(pool_size=(2, 2)))
                

                if n_conv_layers == 1:
                    log_dir_string += "_1conv"
                elif n_conv_layers==2:
                    model.add(Conv2D(16, kernel_size=(5, 5), 
                                     activation='relu', 
                                     kernel_regularizer=regularizers.l2(0.01),
                                     input_shape=input_shape))
                    model.add(MaxPooling2D(pool_size=(2, 2)))
                    log_dir_string += "_2conv"
                else:
                    model.add(Conv2D(16, kernel_size=(5, 5), activation='relu', input_shape=input_shape))
                    model.add(MaxPooling2D(pool_size=(2, 2)))
                    log_dir_string += "_3conv"
                model.add(Flatten())
                model.add(Dense(64, activation='relu'))
                if n_dense_layers == 1:
                    log_dir_string += "_1fc"
                else:
                    model.add(Dense(64, activation='relu'))
                    log_dir_string += "_2fc"

                model.add(Dense(num_classes, activation='sigmoid'))

                #sgd = SGD(lr=0.1, momentum=0.9)
                #model.compile(loss='binary_crossentropy',
                #      optimizer=sgd,
                #      metrics=['accuracy'])
                adam = Adam(lr=lrate)
                #ncce
                model.compile(loss='binary_crossentropy',
                      optimizer=adam,
                      metrics=['accuracy',accuracy_with_threshold, precision_s, recall_s])

                # we need a callback to save information for tensorboard visualizations
                tensorboard = TensorBoard(log_dir='./logs/cv/'+log_dir_string, histogram_freq=1, write_graph=True, write_images=False)

                reduce_lr = ReduceLROnPlateau(monitor='val_accuracy_with_threshold', factor = adaptive_change, patience = 5, min_lr = 0.00001)

                history = model.fit(x_train, y_train,
                            batch_size=batch_size,
                            epochs=epochs,
                            verbose=0,
                            validation_data=(x_test, y_test),
                            callbacks=[tensorboard, reduce_lr])



                score = model.evaluate(x_test, y_test, verbose=0)
                predictions = (model.predict(x_test)>0.1).astype(int)
                print(n_conv_layers, n_dense_layers, lrate, adaptive_change)
                parameters.append([n_conv_layers, n_dense_layers, lrate, adaptive_change])
    
                model_histories.append(history)
                precision = precision_score(y_test, predictions, average="micro")
                recall = recall_score(y_test, predictions, average="micro")
                f1 = f1_score(y_test, predictions, average="micro")
                recalls.append(recall)
                precisions.append(precision)
                f1s.append(f1)
                
                print('Test loss:', score[0])
                print('Test accuracy:', score[1])
                print("Precision: ", precision, "micro, ", precision_score(y_test, predictions, average="macro"), " macro", )
                print("Recall: ", recall, "micro, ", recall_score(y_test, predictions, average="macro"), "macro ") 
                print("F1-score:", f1_score(y_test, predictions, average="micro"), "micro, ", f1_score(y_test, predictions, average="macro"), "macro")
# Out:
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.0005
# Test loss: 0.326033651504
# Test accuracy: 0.916266491137
# Precision:  0.138658902739 micro,  0.0935174001193  macro
# Recall:  0.729535662997 micro,  0.452617149618 macro
# F1-score: 0.233027522936 micro,  0.143315222751 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.0005
# Test loss: 0.315358597283
# Test accuracy: 0.91640654632
# Precision:  0.161782555922 micro,  0.0902113737738  macro
# Recall:  0.669937769268 micro,  0.370044609351 macro
# F1-score: 0.260626658597 micro,  0.139514061452 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.001
# Test loss: 0.309698560814
# Test accuracy: 0.91640654632
# Precision:  0.152958230431 micro,  0.0872203733456  macro
# Recall:  0.681905217808 micro,  0.383612564906 macro
# F1-score: 0.249868444133 micro,  0.137891676582 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.001
# Test loss: 0.306670086076
# Test accuracy: 0.915946362456
# Precision:  0.146261177164 micro,  0.0897927550356  macro
# Recall:  0.71254188607 micro,  0.439354359554 macro
# F1-score: 0.242703407794 micro,  0.142824873927 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.005
# Test loss: 0.277462148018
# Test accuracy: 0.916366528329
# Precision:  0.153399014778 micro,  0.086006489823  macro
# Recall:  0.745332695069 micro,  0.442049808531 macro
# F1-score: 0.254432551679 micro,  0.13362327486 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.005
# Test loss: 0.279456649346
# Test accuracy: 0.91640654632
# Precision:  0.173615988762 micro,  0.0850606020227  macro
# Recall:  0.650789851604 micro,  0.337371109426 macro
# F1-score: 0.27410655779 micro,  0.129210495032 macro
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.01
# Test loss: 0.286013820909
# Test accuracy: 0.91640654632
# Precision:  0.174623539739 micro,  0.0862816452922  macro
# Recall:  0.618956438487 micro,  0.307719110499 macro
# F1-score: 0.272396903144 micro,  0.130977342769 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.01
# Test loss: 0.277031201286
# Test accuracy: 0.91640654632
# Precision:  0.194803174109 micro,  0.0848224081416  macro
# Recall:  0.599329822882 micro,  0.277038941528 macro
# F1-score: 0.294034758102 micro,  0.121390205639 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.1
# Test loss: 1.36385678256
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 1 1 0.1
# Test loss: 1.36635397875
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.0005
# Test loss: 0.34256366613
# Test accuracy: 0.91640654632
# Precision:  0.136611484993 micro,  0.0941203443559  macro
# Recall:  0.665629487793 micro,  0.423980990488 macro
# F1-score: 0.22669655594 micro,  0.127848330747 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.0005
# Test loss: 0.316452537345
# Test accuracy: 0.916146441301
# Precision:  0.16367912535 micro,  0.0952811416895  macro
# Recall:  0.616323599809 micro,  0.334934564933 macro
# F1-score: 0.258663987946 micro,  0.138621126322 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.001
# Test loss: 0.324386423948
# Test accuracy: 0.91640654632
# Precision:  0.118956768026 micro,  0.0821235758156  macro
# Recall:  0.723791287697 micro,  0.53357920992 macro
# F1-score: 0.204331227406 micro,  0.130883417215 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.001
# Test loss: 0.312181144426
# Test accuracy: 0.91640654632
# Precision:  0.138710145629 micro,  0.0874887315747  macro
# Recall:  0.686213499282 micro,  0.429711466167 macro
# F1-score: 0.230772326639 micro,  0.136793159642 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.005
# Test loss: 0.284676531464
# Test accuracy: 0.91640654632
# Precision:  0.143035157988 micro,  0.0882779779065  macro
# Recall:  0.769267592149 micro,  0.476648241663 macro
# F1-score: 0.241218853197 micro,  0.140670002901 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.005
# Test loss: 0.282178275318
# Test accuracy: 0.91640654632
# Precision:  0.138786370269 micro,  0.0820441655377  macro
# Recall:  0.774054571565 micro,  0.474508247244 macro
# F1-score: 0.235371179039 micro,  0.131763803289 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.01
# Test loss: 0.286807923576
# Test accuracy: 0.91640654632
# Precision:  0.210978025087 micro,  0.0918384420318  macro
# Recall:  0.535423647678 micro,  0.238129610951 macro
# F1-score: 0.302685880522 micro,  0.124438247045 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.01
# Test loss: 0.292348073169
# Test accuracy: 0.91640654632
# Precision:  0.143209759339 micro,  0.0847894047132  macro
# Recall:  0.722115844902 micro,  0.425348344652 macro
# F1-score: 0.239017627253 micro,  0.12795230962 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.1
# Test loss: 1.35926647219
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 1 2 0.1
# Test loss: 1.36822461093
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.0005
# Test loss: 0.510538358834
# Test accuracy: 0.865646227768
# Precision:  0.0947986879573 micro,  0.088977858762  macro
# Recall:  0.629487793202 micro,  0.584986054828 macro
# F1-score: 0.164781805081 micro,  0.132872763816 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.0005
# Test loss: 0.470006144128
# Test accuracy: 0.90790313904
# Precision:  0.129913258984 micro,  0.0840844286113  macro
# Recall:  0.627333652465 micro,  0.444257719207 macro
# F1-score: 0.2152506878 micro,  0.123429302377 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.001
# Test loss: 0.42819066737
# Test accuracy: 0.901300491687
# Precision:  0.123700139686 micro,  0.0889957453211  macro
# Recall:  0.763044518909 micro,  0.549933151342 macro
# F1-score: 0.212888146912 micro,  0.146209517451 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.001
# Test loss: 0.403829948837
# Test accuracy: 0.915546202335
# Precision:  0.125635029433 micro,  0.0861360990939  macro
# Recall:  0.745811393011 micro,  0.509964802802 macro
# F1-score: 0.215044858523 micro,  0.138754136736 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.005
# Test loss: 0.311302105586
# Test accuracy: 0.91640654632
# Precision:  0.126083413586 micro,  0.086123647492  macro
# Recall:  0.814743896601 micro,  0.555595545808 macro
# F1-score: 0.218373107519 micro,  0.143048075068 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.005
# Test loss: 0.292445386754
# Test accuracy: 0.91640654632
# Precision:  0.160996533286 micro,  0.0839462967074  macro
# Recall:  0.65581617999 micro,  0.337567313842 macro
# F1-score: 0.258527150068 micro,  0.122001779449 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.01
# Test loss: 0.279529628016
# Test accuracy: 0.91640654632
# Precision:  0.211502782931 micro,  0.0649550124834  macro
# Recall:  0.573001436094 micro,  0.231601137728 macro
# F1-score: 0.308963025102 micro,  0.0934105903822 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.01
# Test loss: 0.273999505221
# Test accuracy: 0.91640654632
# Precision:  0.220392231531 micro,  0.135524398995  macro
# Recall:  0.554092867401 micro,  0.210629008148 macro
# F1-score: 0.315352131862 micro,  0.0984056892768 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.1
# Test loss: 1.41902624571
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 2 1 0.1
# Test loss: 1.41040681803
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.0005
# Test loss: 0.714758347249
# Test accuracy: 0.683393397137
# Precision:  0.0835934373749 micro,  0.0835934373749  macro
# Recall:  1.0 micro,  1.0 macro
# F1-score: 0.154289301673 micro,  0.143553537912 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.0005
# Test loss: 0.448809527459
# Test accuracy: 0.91640654632
# Precision:  0.164022187822 micro,  0.0926738379785  macro
# Recall:  0.608664432743 micro,  0.335417444228 macro
# F1-score: 0.258408698303 micro,  0.133574201385 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.001
# Test loss: 0.441361524296
# Test accuracy: 0.91640654632
# Precision:  0.0892299771535 micro,  0.0738449647168  macro
# Recall:  0.663714696027 micro,  0.610258716288 macro
# F1-score: 0.157311019714 micro,  0.117987095793 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.001
# Test loss: 0.416849644127
# Test accuracy: 0.91640654632
# Precision:  0.11573161486 micro,  0.0842371103283  macro
# Recall:  0.730732407851 micro,  0.549291173437 macro
# F1-score: 0.199816741933 micro,  0.134269541101 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.005
# Test loss: 0.293870516537
# Test accuracy: 0.91640654632
# Precision:  0.155942999028 micro,  0.0814236992259  macro
# Recall:  0.69147917664 micro,  0.384165732442 macro
# F1-score: 0.254492600423 micro,  0.129150026371 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.005
# Test loss: 0.283086854544
# Test accuracy: 0.91640654632
# Precision:  0.177265765466 micro,  0.0761870237645  macro
# Recall:  0.637146960268 micro,  0.30922220789 macro
# F1-score: 0.277363896848 micro,  0.115028726491 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.01
# Test loss: 0.265827351038
# Test accuracy: 0.91640654632
# Precision:  0.205139372822 micro,  0.0762587422638  macro
# Recall:  0.563666826233 micro,  0.232656717381 macro
# F1-score: 0.300804700473 micro,  0.0898654851292 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.01
# Test loss: 0.284250022968
# Test accuracy: 0.91640654632
# Precision:  0.202306342442 micro,  0.0798788622112  macro
# Recall:  0.579463858305 micro,  0.245476046297 macro
# F1-score: 0.299907091979 micro,  0.114174131822 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.1
# Test loss: 1.37212692702
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 2 2 0.1
# Test loss: 1.38803874457
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.0005
# Test loss: 0.323121507152
# Test accuracy: 0.916386539271
# Precision:  0.160386277688 micro,  0.0892000858357  macro
# Recall:  0.568453805649 micro,  0.304231864648 macro
# F1-score: 0.25018434636 micro,  0.130908318327 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.0005
# Test loss: 0.315557930907
# Test accuracy: 0.916346525173
# Precision:  0.179954608683 micro,  0.0850078181376  macro
# Recall:  0.588319770225 micro,  0.284083598335 macro
# F1-score: 0.275606884566 micro,  0.128178682742 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.001
# Test loss: 0.308793162286
# Test accuracy: 0.916206465449
# Precision:  0.140156185779 micro,  0.0833180215876  macro
# Recall:  0.734561991383 micro,  0.446487666036 macro
# F1-score: 0.2353978907 micro,  0.134712513928 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.001
# Test loss: 0.315291743538
# Test accuracy: 0.916366528978
# Precision:  0.131001589825 micro,  0.084837546689  macro
# Recall:  0.788894207755 micro,  0.521682031316 macro
# F1-score: 0.224691526348 micro,  0.140568496968 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.005
# Test loss: 0.285711411513
# Test accuracy: 0.91640654632
# Precision:  0.134829578762 micro,  0.0886973471685  macro
# Recall:  0.770703685974 micro,  0.48845048962 macro
# F1-score: 0.229508196721 micro,  0.141352600477 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.005
# Test loss: 0.275027602222
# Test accuracy: 0.91640654632
# Precision:  0.179578947368 micro,  0.081237021833  macro
# Recall:  0.612494016276 micro,  0.284174282132 macro
# F1-score: 0.277729542001 micro,  0.113528827864 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.01
# Test loss: 0.27267626893
# Test accuracy: 0.91640654632
# Precision:  0.185787240164 micro,  0.0839948903377  macro
# Recall:  0.618238391575 micro,  0.289624421223 macro
# F1-score: 0.285714285714 micro,  0.121567034407 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.01
# Test loss: 0.270610277101
# Test accuracy: 0.91640654632
# Precision:  0.166413640079 micro,  0.0912176310809  macro
# Recall:  0.682144566778 micro,  0.35084023827 macro
# F1-score: 0.267555388659 micro,  0.113209850057 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.1
# Test loss: 1.35440312827
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# 3 1 0.1
# Test loss: 1.36593078578
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.0005
# Test loss: 0.385511929892
# Test accuracy: 0.91626649057
# Precision:  0.101293568092 micro,  0.0863344078624  macro
# Recall:  0.674724748684 micro,  0.560991477824 macro
# F1-score: 0.176143464134 micro,  0.123431421592 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.0005
# Test loss: 0.378083015056
# Test accuracy: 0.916026393572
# Precision:  0.0941655801825 micro,  0.0812934574058  macro
# Recall:  0.69147917664 micro,  0.621522861459 macro
# F1-score: 0.16575821906 micro,  0.12846632916 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.001
# Test loss: 0.328440838485
# Test accuracy: 0.901340507488
# Precision:  0.114630006789 micro,  0.0906634819059  macro
# Recall:  0.80828147439 micro,  0.625534692216 macro
# F1-score: 0.200784826684 micro,  0.150064792056 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.001
# Test loss: 0.326730391322
# Test accuracy: 0.9123449195
# Precision:  0.117990993608 micro,  0.0875192378829  macro
# Recall:  0.777644806127 micro,  0.585581710874 macro
# F1-score: 0.204893737781 micro,  0.142415621882 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.005
# Test loss: 0.271342317871
# Test accuracy: 0.91640654632
# Precision:  0.187285616282 micro,  0.0850451775841  macro
# Recall:  0.588080421254 micro,  0.264516501901 macro
# F1-score: 0.284095507892 micro,  0.114984803244 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.005
# Test loss: 0.277844877997
# Test accuracy: 0.91640654632
# Precision:  0.132977000324 micro,  0.0836936148353  macro
# Recall:  0.786022020105 micro,  0.496302702622 macro
# F1-score: 0.22747108125 micro,  0.130604634069 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.01
# Test loss: 0.272355691916
# Test accuracy: 0.91640654632
# Precision:  0.179082119025 micro,  0.0825359847105  macro
# Recall:  0.629487793202 micro,  0.310811559364 macro
# F1-score: 0.278837998304 micro,  0.12516192147 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.01
# Test loss: 0.305413417792
# Test accuracy: 0.91640654632
# Precision:  0.107888369999 micro,  0.0876390443656  macro
# Recall:  0.917903303016 micro,  0.737027599819 macro
# F1-score: 0.193082267647 micro,  0.146281617037 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.1
# Test loss: 1.36261784041
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name conv2d_2/kernel:0 is illegal; using conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_2/bias:0 is illegal; using conv2d_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# INFO:tensorflow:Summary name dense_3/kernel:0 is illegal; using dense_3/kernel_0 instead.
# INFO:tensorflow:Summary name dense_3/bias:0 is illegal; using dense_3/bias_0 instead.
# 3 2 0.1
# Test loss: 1.36115025485
# Test accuracy: 0.91640654632
# Precision:  0.0 micro,  0.0  macro
# Recall:  0.0 micro,  0.0 macro
# F1-score: 0.0 micro,  0.0 macro

# %%
max_index = np.array(f1s).argmax()
print("Best performance", max_index)
parameters[max_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e62cca255ea4> in <module>()
# ----> 1 max_index = np.array(f1s).argmax()
#       2 print("Best performance", max_index)
#       3 parameters[max_index]
#
# NameError: name 'f1s' is not defined

# %%
batch_size=256 
epochs=50
n_conv_layers = 1 #parameters[max_index][0]
n_dense_layers = 1 #parameters[max_index][1]
lrate = 0.001 #parameters[max_index][2]
adaptive_change = 0.01

log_dir_string = "cv"
log_dir_string += str(lrate)
log_dir_string += str(adaptive_change)
K.clear_session()
model = Sequential()
model.add(Conv2D(16, kernel_size=(5, 5), 
                 activation='relu', 
                 kernel_regularizer=regularizers.l2(0.01),
                 input_shape=input_shape))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2)))


if n_conv_layers == 1:
    log_dir_string += "_1conv"
elif n_conv_layers==2:
    model.add(Conv2D(16, kernel_size=(5, 5), 
                     activation='relu', 
                     kernel_regularizer=regularizers.l2(0.01),
                     input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    log_dir_string += "_2conv"
else:
    model.add(Conv2D(16, kernel_size=(5, 5), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    log_dir_string += "_3conv"
model.add(Flatten())
model.add(Dense(64, activation='relu'))
if n_dense_layers == 1:
    log_dir_string += "_1fc"
else:
    model.add(Dense(64, activation='relu'))
    log_dir_string += "_2fc"

model.add(Dense(num_classes, activation='sigmoid'))

adam = Adam(lr=lrate)
#ncce
model.compile(loss='binary_crossentropy',
      optimizer=adam,
      metrics=['accuracy',accuracy_with_threshold, precision_s, recall_s])

# we need a callback to save information for tensorboard visualizations
tensorboard = TensorBoard(log_dir='./logs/cv/'+log_dir_string, histogram_freq=1, write_graph=True, write_images=False)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy_with_threshold', factor = adaptive_change, patience = 5, min_lr = 0.00001)

history = model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            validation_data=(x_test, y_test),
            callbacks=[tensorboard, reduce_lr])



score = model.evaluate(x_test, y_test, verbose=0)
predictions = (model.predict(x_test)>0.1).astype(int)
print(n_conv_layers, n_dense_layers, lrate, adaptive_change)

precision = precision_score(y_test, predictions, average="micro")
recall = recall_score(y_test, predictions, average="micro")
f1 = f1_score(y_test, predictions, average="micro")

print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Precision: ", precision, "micro, ", precision_score(y_test, predictions, average="macro"), " macro", )
print("Recall: ", recall, "micro, ", recall_score(y_test, predictions, average="macro"), "macro ") 
print("F1-score:", f1_score(y_test, predictions, average="micro"), "micro, ", f1_score(y_test, predictions, average="macro"), "macro")
# Out:
# Train on 11757 samples, validate on 2940 samples
# INFO:tensorflow:Summary name conv2d_1/kernel:0 is illegal; using conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2d_1/bias:0 is illegal; using conv2d_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_1/kernel:0 is illegal; using dense_1/kernel_0 instead.
# INFO:tensorflow:Summary name dense_1/bias:0 is illegal; using dense_1/bias_0 instead.
# INFO:tensorflow:Summary name dense_2/kernel:0 is illegal; using dense_2/kernel_0 instead.
# INFO:tensorflow:Summary name dense_2/bias:0 is illegal; using dense_2/bias_0 instead.
# Epoch 1/50
# 11757/11757 [==============================] - 25s - loss: 0.3347 - acc: 0.9057 - accuracy_with_threshold: 0.6696 - precision_s: 0.1662 - recall_s: 0.6379 - val_loss: 0.2971 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6323 - val_precision_s: 0.1477 - val_recall_s: 0.7120
# Epoch 2/50
# 11757/11757 [==============================] - 23s - loss: 0.2810 - acc: 0.9172 - accuracy_with_threshold: 0.7709 - precision_s: 0.2047 - recall_s: 0.6077 - val_loss: 0.2779 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6977 - val_precision_s: 0.1732 - val_recall_s: 0.6934
# Epoch 3/50
# 11757/11757 [==============================] - 24s - loss: 0.2668 - acc: 0.9172 - accuracy_with_threshold: 0.7861 - precision_s: 0.2190 - recall_s: 0.6118 - val_loss: 0.2716 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6297 - val_precision_s: 0.1553 - val_recall_s: 0.7734
# Epoch 4/50
# 11757/11757 [==============================] - 29s - loss: 0.2579 - acc: 0.9171 - accuracy_with_threshold: 0.7864 - precision_s: 0.2213 - recall_s: 0.6233 - val_loss: 0.2624 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6631 - val_precision_s: 0.1655 - val_recall_s: 0.7507
# Epoch 5/50
# 11757/11757 [==============================] - 28s - loss: 0.2514 - acc: 0.9173 - accuracy_with_threshold: 0.7895 - precision_s: 0.2256 - recall_s: 0.6265 - val_loss: 0.2568 - val_acc: 0.9165 - val_accuracy_with_threshold: 0.7123 - val_precision_s: 0.1835 - val_recall_s: 0.7082
# Epoch 6/50
# 11757/11757 [==============================] - 27s - loss: 0.2478 - acc: 0.9172 - accuracy_with_threshold: 0.7890 - precision_s: 0.2261 - recall_s: 0.6304 - val_loss: 0.2562 - val_acc: 0.9165 - val_accuracy_with_threshold: 0.6477 - val_precision_s: 0.1624 - val_recall_s: 0.7737
# Epoch 7/50
# 11757/11757 [==============================] - 28s - loss: 0.2441 - acc: 0.9174 - accuracy_with_threshold: 0.7904 - precision_s: 0.2294 - recall_s: 0.6375 - val_loss: 0.2528 - val_acc: 0.9165 - val_accuracy_with_threshold: 0.6965 - val_precision_s: 0.1789 - val_recall_s: 0.7340
# Epoch 8/50
# 11757/11757 [==============================] - 23s - loss: 0.2417 - acc: 0.9173 - accuracy_with_threshold: 0.7923 - precision_s: 0.2309 - recall_s: 0.6409 - val_loss: 0.2512 - val_acc: 0.9163 - val_accuracy_with_threshold: 0.6942 - val_precision_s: 0.1770 - val_recall_s: 0.7290
# Epoch 9/50
# 11757/11757 [==============================] - 27s - loss: 0.2409 - acc: 0.9174 - accuracy_with_threshold: 0.7908 - precision_s: 0.2313 - recall_s: 0.6450 - val_loss: 0.2474 - val_acc: 0.9165 - val_accuracy_with_threshold: 0.7223 - val_precision_s: 0.1907 - val_recall_s: 0.7164
# Epoch 10/50
# 11757/11757 [==============================] - 23s - loss: 0.2390 - acc: 0.9173 - accuracy_with_threshold: 0.7912 - precision_s: 0.2328 - recall_s: 0.6516 - val_loss: 0.2566 - val_acc: 0.9162 - val_accuracy_with_threshold: 0.5949 - val_precision_s: 0.1502 - val_recall_s: 0.8268
# Epoch 11/50
# 11757/11757 [==============================] - 25s - loss: 0.2380 - acc: 0.9175 - accuracy_with_threshold: 0.7893 - precision_s: 0.2317 - recall_s: 0.6543 - val_loss: 0.2501 - val_acc: 0.9165 - val_accuracy_with_threshold: 0.6634 - val_precision_s: 0.1695 - val_recall_s: 0.7772
# Epoch 12/50
# 11757/11757 [==============================] - 24s - loss: 0.2374 - acc: 0.9172 - accuracy_with_threshold: 0.7878 - precision_s: 0.2317 - recall_s: 0.6644 - val_loss: 0.2475 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6805 - val_precision_s: 0.1748 - val_recall_s: 0.7591
# Epoch 13/50
# 11757/11757 [==============================] - 23s - loss: 0.2356 - acc: 0.9176 - accuracy_with_threshold: 0.7915 - precision_s: 0.2341 - recall_s: 0.6618 - val_loss: 0.2490 - val_acc: 0.9164 - val_accuracy_with_threshold: 0.6703 - val_precision_s: 0.1722 - val_recall_s: 0.7737
# Epoch 14/50
# 11757/11757 [==============================] - 22s - loss: 0.2351 - acc: 0.9177 - accuracy_with_threshold: 0.7903 - precision_s: 0.2344 - recall_s: 0.6652 - val_loss: 0.2470 - val_acc: 0.9161 - val_accuracy_with_threshold: 0.6998 - val_precision_s: 0.1824 - val_recall_s: 0.7447
# Epoch 15/50
# 11757/11757 [==============================] - 24s - loss: 0.2344 - acc: 0.9177 - accuracy_with_threshold: 0.7927 - precision_s: 0.2368 - recall_s: 0.6703 - val_loss: 0.2524 - val_acc: 0.9166 - val_accuracy_with_threshold: 0.6295 - val_precision_s: 0.1599 - val_recall_s: 0.8077
# Epoch 16/50
# 11757/11757 [==============================] - 23s - loss: 0.2326 - acc: 0.9178 - accuracy_with_threshold: 0.7775 - precision_s: 0.2272 - recall_s: 0.6991 - val_loss: 0.2468 - val_acc: 0.9166 - val_accuracy_with_threshold: 0.6822 - val_precision_s: 0.1771 - val_recall_s: 0.7694
# Epoch 17/50
# 11757/11757 [==============================] - 23s - loss: 0.2320 - acc: 0.9180 - accuracy_with_threshold: 0.7920 - precision_s: 0.2369 - recall_s: 0.6808 - val_loss: 0.2470 - val_acc: 0.9166 - val_accuracy_with_threshold: 0.6797 - val_precision_s: 0.1760 - val_recall_s: 0.7701
# Epoch 18/50
# 11757/11757 [==============================] - 22s - loss: 0.2319 - acc: 0.9181 - accuracy_with_threshold: 0.7935 - precision_s: 0.2380 - recall_s: 0.6791 - val_loss: 0.2470 - val_acc: 0.9167 - val_accuracy_with_threshold: 0.6795 - val_precision_s: 0.1759 - val_recall_s: 0.7696
# Epoch 19/50
# 11757/11757 [==============================] - 24s - loss: 0.2319 - acc: 0.9181 - accuracy_with_threshold: 0.7932 - precision_s: 0.2378 - recall_s: 0.6789 - val_loss: 0.2471 - val_acc: 0.9167 - val_accuracy_with_threshold: 0.6777 - val_precision_s: 0.1750 - val_recall_s: 0.7698
# Epoch 20/50
# 11757/11757 [==============================] - 25s - loss: 0.2318 - acc: 0.9181 - accuracy_with_threshold: 0.7929 - precision_s: 0.2377 - recall_s: 0.6805 - val_loss: 0.2467 - val_acc: 0.9168 - val_accuracy_with_threshold: 0.6816 - val_precision_s: 0.1762 - val_recall_s: 0.7651
# Epoch 21/50
# 11757/11757 [==============================] - 37s - loss: 0.2318 - acc: 0.9180 - accuracy_with_threshold: 0.7955 - precision_s: 0.2397 - recall_s: 0.6768 - val_loss: 0.2468 - val_acc: 0.9168 - val_accuracy_with_threshold: 0.6811 - val_precision_s: 0.1759 - val_recall_s: 0.7651
# Epoch 22/50
# 11757/11757 [==============================] - 28s - loss: 0.2318 - acc: 0.9181 - accuracy_with_threshold: 0.7935 - precision_s: 0.2380 - recall_s: 0.6785 - val_loss: 0.2466 - val_acc: 0.9168 - val_accuracy_with_threshold: 0.6829 - val_precision_s: 0.1766 - val_recall_s: 0.7634
# Epoch 23/50
# 11757/11757 [==============================] - 28s - loss: 0.2317 - acc: 0.9182 - accuracy_with_threshold: 0.7947 - precision_s: 0.2391 - recall_s: 0.6775 - val_loss: 0.2468 - val_acc: 0.9168 - val_accuracy_with_threshold: 0.6804 - val_precision_s: 0.1757 - val_recall_s: 0.7658
# Epoch 24/50
# 11757/11757 [==============================] - 26s - loss: 0.2318 - acc: 0.9181 - accuracy_with_threshold: 0.7949 - precision_s: 0.2394 - recall_s: 0.6786 - val_loss: 0.2469 - val_acc: 0.9167 - val_accuracy_with_threshold: 0.6787 - val_precision_s: 0.1752 - val_recall_s: 0.7674
# Epoch 25/50
# 11757/11757 [==============================] - 24s - loss: 0.2317 - acc: 0.9181 - accuracy_with_threshold: 0.7948 - precision_s: 0.2391 - recall_s: 0.6776 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6784 - val_precision_s: 0.1752 - val_recall_s: 0.7686
# Epoch 26/50
# 11757/11757 [==============================] - 25s - loss: 0.2317 - acc: 0.9182 - accuracy_with_threshold: 0.7947 - precision_s: 0.2391 - recall_s: 0.6783 - val_loss: 0.2468 - val_acc: 0.9168 - val_accuracy_with_threshold: 0.6804 - val_precision_s: 0.1757 - val_recall_s: 0.7653
# Epoch 27/50
# 11757/11757 [==============================] - 31s - loss: 0.2317 - acc: 0.9181 - accuracy_with_threshold: 0.7942 - precision_s: 0.2389 - recall_s: 0.6795 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6787 - val_precision_s: 0.1752 - val_recall_s: 0.7679
# Epoch 28/50
# 11757/11757 [==============================] - 29s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7962 - precision_s: 0.2404 - recall_s: 0.6769 - val_loss: 0.2473 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6743 - val_precision_s: 0.1736 - val_recall_s: 0.7710
# Epoch 29/50
# 11757/11757 [==============================] - 31s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7931 - precision_s: 0.2380 - recall_s: 0.6805 - val_loss: 0.2466 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6837 - val_precision_s: 0.1765 - val_recall_s: 0.7600
# Epoch 30/50
# 11757/11757 [==============================] - 30s - loss: 0.2316 - acc: 0.9182 - accuracy_with_threshold: 0.7958 - precision_s: 0.2402 - recall_s: 0.6778 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6780 - val_precision_s: 0.1749 - val_recall_s: 0.7679
# Epoch 31/50
# 11757/11757 [==============================] - 31s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7947 - precision_s: 0.2395 - recall_s: 0.6803 - val_loss: 0.2468 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6809 - val_precision_s: 0.1758 - val_recall_s: 0.7648
# Epoch 32/50
# 11757/11757 [==============================] - 29s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7942 - precision_s: 0.2390 - recall_s: 0.6801 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6783 - val_precision_s: 0.1750 - val_recall_s: 0.7674
# Epoch 33/50
# 11757/11757 [==============================] - 25s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7950 - precision_s: 0.2394 - recall_s: 0.6777 - val_loss: 0.2471 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6773 - val_precision_s: 0.1745 - val_recall_s: 0.7674
# Epoch 34/50
# 11757/11757 [==============================] - 26s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7951 - precision_s: 0.2398 - recall_s: 0.6795 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6787 - val_precision_s: 0.1750 - val_recall_s: 0.7660
# Epoch 35/50
# 11757/11757 [==============================] - 30s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7945 - precision_s: 0.2394 - recall_s: 0.6808 - val_loss: 0.2474 - val_acc: 0.9170 - val_accuracy_with_threshold: 0.6732 - val_precision_s: 0.1732 - val_recall_s: 0.7717
# Epoch 36/50
# 11757/11757 [==============================] - 31s - loss: 0.2315 - acc: 0.9182 - accuracy_with_threshold: 0.7956 - precision_s: 0.2397 - recall_s: 0.6759 - val_loss: 0.2471 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6764 - val_precision_s: 0.1740 - val_recall_s: 0.7674
# Epoch 37/50
# 11757/11757 [==============================] - 25s - loss: 0.2316 - acc: 0.9181 - accuracy_with_threshold: 0.7930 - precision_s: 0.2383 - recall_s: 0.6826 - val_loss: 0.2471 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6767 - val_precision_s: 0.1742 - val_recall_s: 0.7669
# Epoch 38/50
# 11757/11757 [==============================] - 29s - loss: 0.2315 - acc: 0.9181 - accuracy_with_threshold: 0.7948 - precision_s: 0.2392 - recall_s: 0.6780 - val_loss: 0.2472 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6760 - val_precision_s: 0.1740 - val_recall_s: 0.7679
# Epoch 39/50
# 11757/11757 [==============================] - 25s - loss: 0.2315 - acc: 0.9181 - accuracy_with_threshold: 0.7940 - precision_s: 0.2389 - recall_s: 0.6804 - val_loss: 0.2468 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6802 - val_precision_s: 0.1755 - val_recall_s: 0.7648
# Epoch 40/50
# 11757/11757 [==============================] - 25s - loss: 0.2315 - acc: 0.9180 - accuracy_with_threshold: 0.7946 - precision_s: 0.2393 - recall_s: 0.6797 - val_loss: 0.2467 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6821 - val_precision_s: 0.1762 - val_recall_s: 0.7631
# Epoch 41/50
# 11757/11757 [==============================] - 33s - loss: 0.2315 - acc: 0.9181 - accuracy_with_threshold: 0.7948 - precision_s: 0.2393 - recall_s: 0.6790 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6783 - val_precision_s: 0.1749 - val_recall_s: 0.7667
# Epoch 42/50
# 11757/11757 [==============================] - 25s - loss: 0.2315 - acc: 0.9182 - accuracy_with_threshold: 0.7945 - precision_s: 0.2390 - recall_s: 0.6784 - val_loss: 0.2471 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6769 - val_precision_s: 0.1743 - val_recall_s: 0.7674
# Epoch 43/50
# 11757/11757 [==============================] - 30s - loss: 0.2315 - acc: 0.9181 - accuracy_with_threshold: 0.7945 - precision_s: 0.2394 - recall_s: 0.6809 - val_loss: 0.2470 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6786 - val_precision_s: 0.1750 - val_recall_s: 0.7665
# Epoch 44/50
# 11757/11757 [==============================] - 26s - loss: 0.2315 - acc: 0.9182 - accuracy_with_threshold: 0.7948 - precision_s: 0.2393 - recall_s: 0.6781 - val_loss: 0.2469 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6792 - val_precision_s: 0.1752 - val_recall_s: 0.7662
# Epoch 45/50
# 11757/11757 [==============================] - 26s - loss: 0.2315 - acc: 0.9182 - accuracy_with_threshold: 0.7930 - precision_s: 0.2379 - recall_s: 0.6810 - val_loss: 0.2468 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6807 - val_precision_s: 0.1757 - val_recall_s: 0.7648
# Epoch 46/50
# 11757/11757 [==============================] - 33s - loss: 0.2314 - acc: 0.9181 - accuracy_with_threshold: 0.7948 - precision_s: 0.2394 - recall_s: 0.6790 - val_loss: 0.2467 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6817 - val_precision_s: 0.1762 - val_recall_s: 0.7643
# Epoch 47/50
# 11757/11757 [==============================] - 31s - loss: 0.2314 - acc: 0.9181 - accuracy_with_threshold: 0.7939 - precision_s: 0.2387 - recall_s: 0.6799 - val_loss: 0.2466 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6833 - val_precision_s: 0.1766 - val_recall_s: 0.7619
# Epoch 48/50
# 11757/11757 [==============================] - 25s - loss: 0.2314 - acc: 0.9181 - accuracy_with_threshold: 0.7940 - precision_s: 0.2391 - recall_s: 0.6817 - val_loss: 0.2465 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6849 - val_precision_s: 0.1773 - val_recall_s: 0.7614
# Epoch 49/50
# 11757/11757 [==============================] - 26s - loss: 0.2314 - acc: 0.9182 - accuracy_with_threshold: 0.7946 - precision_s: 0.2389 - recall_s: 0.6770 - val_loss: 0.2473 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6745 - val_precision_s: 0.1736 - val_recall_s: 0.7702
# Epoch 50/50
# 11757/11757 [==============================] - 25s - loss: 0.2314 - acc: 0.9180 - accuracy_with_threshold: 0.7936 - precision_s: 0.2383 - recall_s: 0.6799 - val_loss: 0.2468 - val_acc: 0.9169 - val_accuracy_with_threshold: 0.6814 - val_precision_s: 0.1761 - val_recall_s: 0.7648
# 1 1 0.001 0.01
# Test loss: 0.246758303553
# Test accuracy: 0.916926753521
# Precision:  0.176042356056 micro,  0.114988622736  macro
# Recall:  0.764367816092 micro,  0.493672661416 macro
# F1-score: 0.286175363098 micro,  0.174558457194 macro
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# //anaconda/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from matplotlib.pyplot import imshow
probabilities = model.predict(x_test)

# %%
for genre in range(len(genre_names)):
    print(genre_names[genre], ": Most representative posters")
    top_indices = probabilities[:,genre].argsort()[-8:][::-1]
    #print(top_indices)
    for index in range(len(top_indices)):
        image_fname = test_indices[top_indices[index]]
        plt.subplot(1, len(top_indices),index+1)
        pil_im = Image.open('Movie Posters Resized 32x32/'+image_fname, 'r')
        plt.imshow(np.asarray(pil_im))
        plt.xticks([])
        plt.yticks([])
    plt.show()
# Out:
# Action : Most representative posters
# Adventure : Most representative posters
# Animation : Most representative posters
# Comedy : Most representative posters
# Crime : Most representative posters
# Documentary : Most representative posters
# Drama : Most representative posters
# Family : Most representative posters
# Fantasy : Most representative posters
# History : Most representative posters
# Horror : Most representative posters
# Mystery : Most representative posters
# Romance : Most representative posters
# Science Fiction : Most representative posters
# Thriller : Most representative posters
# War : Most representative posters
# Western : Most representative posters

# %% [markdown]
# ### Visualize accuracy as a function of training epoch

# %%
#here is a visualization of the training process
#typically we gain a lot in the beginning and then
#training slows down
for history in model_histories:
   plt.plot(history.history['acc'])
   plt.xlabel("epoch")
   plt.ylabel("accuracy")
   plt.show()

# %% [markdown]
# ### Get the weights from the first layer and visualize

# %%
# Look at the weights of the first layer
layer = model.layers[0]
# this actually returns a list 
# first element is W
# second element are all the biases b
weights = layer.get_weights()
# the weights are the number of pixels times the number of filters (hidden units)
print("Shape of W")
print(weights[0].shape)

# look at just the first filter
w = weights[0][:,:,0,0]
w = w.reshape((5,5))
plt.imshow(w, cmap='gray')
# Out:
# Shape of W
# (5, 5, 3, 16)

# %% [markdown]
# ### Visualize the weights from the first 25 filters

# %%
# make a figure for the first 25 filters
filterTiles = np.array([])
index = 0
for i in range(4):
    filterRow = []
    for j in range(4):
        w = weights[0][:,:,0,index]
        w = w.reshape(5,5)
        w = w-np.min(w)
        w = w / np.max(w)
        filterRow.extend(w)
        index+=1
    filterRow = np.array(filterRow)
    if not filterTiles.shape[0] == 0:
        filterTiles = np.hstack([filterTiles, filterRow])
    else:
        filterTiles = filterRow

plt.imshow(filterTiles, cmap='gray')    
plt.show()

# %%
# make a figure for the first 25 filters
index = 0
for i in range(4):
    for j in range(4):
        w = weights[0][:,:,0,index]
        w = w.reshape(5,5)
        index+=1
        plt.subplot(4,4,index)
        plt.imshow(w, cmap='gray')    

plt.show()
